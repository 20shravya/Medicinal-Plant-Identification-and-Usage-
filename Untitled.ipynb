# %%
from pathlib import Path

BASE = Path(r"C:\MedicinalPlantApp")

print("Model exists:", (BASE/"models"/"plant_model.h5").exists())
print("Class indices exists:", (BASE/"models"/"class_indices.json").exists())
# Out:
# Model exists: True
# Class indices exists: True
