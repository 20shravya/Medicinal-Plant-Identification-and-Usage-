# %%
from pathlib import Path
BASE = Path(r"C:\MedicinalPlantApp")
examples = list((BASE/"data"/"val").rglob("*.*"))[:20]   # first 20 files
for p in examples:
    print(p)
# Out:
# C:\MedicinalPlantApp\data\val\.ipynb_checkpoints
# C:\MedicinalPlantApp\data\val\Arive-Dantu\__100_1138909.png
# C:\MedicinalPlantApp\data\val\Arive-Dantu\__100_5048022.png
# C:\MedicinalPlantApp\data\val\Arive-Dantu\__101_5762424.png
# C:\MedicinalPlantApp\data\val\Arive-Dantu\__102_4927806.png
# C:\MedicinalPlantApp\data\val\Arive-Dantu\__102_994488.png
# C:\MedicinalPlantApp\data\val\Arive-Dantu\__103_1047738.png
# C:\MedicinalPlantApp\data\val\Arive-Dantu\__104_8001867.png
# C:\MedicinalPlantApp\data\val\Arive-Dantu\__107_1084783.png
# C:\MedicinalPlantApp\data\val\Arive-Dantu\__107_2113231.png
# C:\MedicinalPlantApp\data\val\Arive-Dantu\__110_3735023.png
# C:\MedicinalPlantApp\data\val\Arive-Dantu\__111_2131281.png
# C:\MedicinalPlantApp\data\val\Arive-Dantu\__112_4335387.png
# C:\MedicinalPlantApp\data\val\Arive-Dantu\__112_8764290.png
# C:\MedicinalPlantApp\data\val\Arive-Dantu\__114_5799509.png
# C:\MedicinalPlantApp\data\val\Arive-Dantu\__115_4048725.png
# ...
